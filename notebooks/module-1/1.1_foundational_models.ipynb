# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")
# model.invoke(): Send a request to the model and get a response back

response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government or sovereign status, so it has no capital. If you’re thinking of a science fiction setting, authors sometimes invent a lunar capital, but that would be fictional. If you tell me which universe or book you have in mind, I can tell you what that story calls its capital.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 844, 'prompt_tokens': 13, 'total_tokens': 857, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D3zldFNB2Hi3eiBBuvCMY5twfUKmH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c12f8-4d01-7f71-a9f3-718566f19b15-0', usage_metadata={'input_tokens': 13, 'output_tokens': 844, 'total_tokens': 857, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or sovereign status, so it has no capital. If you’re thinking of a science fiction setting, authors sometimes invent a lunar capital, but that would be fictional. If you tell me which universe or book you have in mind, I can tell you what that story calls its capital.

# %%
from pprint import pprint

pprint(response.response_metadata)  # Metadata about the response
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-D3zldFNB2Hi3eiBBuvCMY5twfUKmH',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 844,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 768,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 857}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature = 1.0   # Controls randomness of output
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon has no government or cities, so it has no capital. If humanity ever establishes a lunar settlement or nation, they could designate a capital then. (In science fiction you’ll see various invented capitals, but nothing real yet.)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent 

agent = create_agent(model = model)    # Create an agent - base chat model

# %%
agent = create_agent(model = "claude-sonnet-4-5")

# %%
agent = create_agent(model = "gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)   # Print the response
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='a0265d38-f92a-4b4d-b5c6-313ff30749d8'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or capital. If humans ever establish settlements, a “capital” would be a matter of future agreements and hasn’t been decided yet. If you want, I can brainstorm some fictional name ideas.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 575, 'prompt_tokens': 13, 'total_tokens': 588, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D3zyj6ZmDZvXcaTvI7pCBDTZxdNto', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c1304-b570-7e83-96c2-aa447f4474bb-0', usage_metadata={'input_tokens': 13, 'output_tokens': 575, 'total_tokens': 588, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}

# %%
print(response['messages'][-1].content)    # Print the last message
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. If humans ever establish settlements, a “capital” would be a matter of future agreements and hasn’t been decided yet. If you want, I can brainstorm some fictional name ideas.

# %%
from langchain.messages import AIMessage
# Provide conversation history to the agent
# Since these basic models do not have memory (stateless), 
# we need to provide the conversation history if we want it understand the context
response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='a5c0d42b-f62f-476c-9144-d275aeb9cd15'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='6a5d4b68-6796-410a-b7d6-b8b138c585d7'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='3aad5976-7ffa-4615-a528-78f7add4db99'),
#               AIMessage(content='Quick correction: there isn’t a real capital of the Moon. The Moon isn’t a country or sovereign entity, so there’s no Luna City in actuality. If you’d like, I can either (a) spin up a fully fictional description of Luna City, or (b) give you a grounded, near-future concept of what a lunar city might be like based on current technologies and plans. Which do you prefer? In the meantime, here’s a tasty fictional take you can use or tweak:\n\nFictional concept: Luna City (a sci-fi city on the Moon)\n\n- Location and setting\n  - Built in a shielded lava tube near the Shackleton crater at the lunar south pole, with access to subsurface ice deposits for water and oxygen.\n  - Architecture uses a mix of underground habitats and surface domes to shield residents from radiation and micrometeoroids.\n\n- Government and society\n  - A city-state governed by the Luna Council, with representatives from Earth, lunar scientists, engineers, and civic leaders.\n  - Currency is a renewable “Moon Credit” used for cross-city trade with Earth and other lunar settlements.\n  - Legal framework blends international space law with local ordinances on habitation, resource use, and education.\n\n- Daily life and culture\n  - Population: roughly tens of thousands with a steady influx of researchers, miners, engineers, and families.\n  - Day-to-day routines are synchronized to a 24-hour schedule, but power and life support run on continuously closed-loop systems.\n  - Culture emphasizes resilience, exploration, and interplanetary cooperation; schools teach both Earth history and lunar sciences; art and music celebrate Earth and space exploration.\n\n- Economy and infrastructure\n  - Core industries: water ice extraction and purification, oxygen production, solar energy farms, 3D-printed construction from regolith, and limited in-situ manufacturing.\n  - Tourism to illuminated crater rims and ice-lit skylines; private research labs conducting astronomy, heliophysics, and biology in microgravity.\n  - Transportation includes hover- or wheel-based lunar rovers, surface tram lines along the crater rim, and fixed transit hubs.\n\n- Technology and housing\n  - Subsurface habitats shield residents from radiation; surface domes host greenhouses, schools, and markets.\n  - Life support is a closed-loop system with water recycling, hydroponic farms, and algae bioreactors for oxygen.\n  - Construction relies on 3D-printed concrete-like regolith composites and inflatable modules for rapid expansion.\n\n- Challenges and priorities\n  - Radiation, regolith dust, micrometeorite impacts, and the psychological effects of a long lunar day (and long lunar night) are ongoing concerns.\n  - Sustainability: keeping energy, water, and life support reserves balanced; ensuring safe lifting-and-landing zones for resupply missions.\n  - Governance: coordinating with Earth authorities, other lunar settlements, and international partners.\n\nIf you want, I can tailor this to a specific vibe—hard sci-fi with strict engineering constraints, space-opera grandeur, or a cozy, utopian colony. I can also write a short scene or a world bible (maps, key figures, timelines) for Luna City. Do you want a quick scene set there, or a longer backstory outline?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2530, 'prompt_tokens': 40, 'total_tokens': 2570, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1856, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D3zzgiwe9pOVGdsWVrmHXZiNl64oL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c1305-979e-7663-be42-180c9685395d-0', usage_metadata={'input_tokens': 40, 'output_tokens': 2530, 'total_tokens': 2570, 'input_token_detai ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):
    # agent.stream() = stream the answer
    # token = small chunk of answer
    # metadata = extra info where this chunk came from
    
    if token.content:  # token.content = actual content of the token
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City isn’t a real place today, but I can give you a rich, fully fleshed-out fictional concept for Luna City as the capital of the Moon. If you’re writing fiction, world-building game lore, or just speculating about future lunar civilization, this should be a solid foundation you can use or adapt.
#
# Overview
# - Name: Luna City (officially the Capital of the Moon, seat of the Lunar Union)
# - Government: A constitutional-lunar federation with a central City Council (the Sovereign Council) and a City Administrator who acts as mayor. The council represents districts, resource sectors, and scientific institutions. There’s a Earth-Lunar Accord that regulates interplanetary relations and resource sharing.
# - Population: Approximately 3 million residents by mid-22nd century in its core, with satellite settlements across the near-pole rim and shadowed craters supplying water ice and minerals.
# - Flag/Symbol: A silver crescent cradling a blue orbital ring, signifying resilience, exploration, and the unity between Moon and Earth.
# - Motto: “In light we endure; from shadow we build.”
#
# Location and Geography
# - General setting: A sprawling hub along the rim of a permanently sunlit canyon at the lunar south pole region, with access to both near-continuous solar energy and abundant water ice from nearby shadowed craters.
# - Environment: Vacuum, extreme temperature swings, high radiation outside shielded habitats. Habitats are carved into regolith or built as modular, inflatable-then-fortified structures. Shielding uses regolith layering, water as a radiation barrier, and magnetic/radiative protection tech.
# - City plan concept: A layered, multi-district metropolis with several vertical layers (surface plazas, mid-city neighborhoods embedded in the rim, and underground industrial/commercial zones). Transit connects these layers via light-rails, magnetic-lev trams, and airlock-linked pedestrian corridors.
#
# Key Districts and Features
# - Central Spire District: The political and administrative heart, home to the Sovereign Council chambers, the City Library and Archives, and the Grand Observatory. A spiraling tower complex integrated with a media and education hub.
# - Sol Gate District: The commercial core with lunar markets, generic and luxury housing, fintech hubs, and the main spaceport access. A bright, glassy district with solar canopies and reflective coatings.
# - Waterworks Quarter: Industrial and residential zone focused on ISRU (in-situ resource utilization) processing, water extraction facilities, fuel synthesis, and hydroponics labs. Includes underground saline ponds used for algae farms and air scrubbing.
# - Knowledge Quarter: Universities, research institutes, robotics labs, and interplanetary think tanks. A campus-city hybrid with open-air plazas, holographic display gardens, and gravity-friendly art installations.
# - Harbor District (Luna Dock): The lunar port and logistics hub for cargo, mining, and passenger traffic. Includes freight elevators, rail tethers, a lunar elevator system, and repair yards for landers and transfer habitats.
# - Night Market Crescent: A cultural and artistic enclave near the rim that thrives in the near-constant daylight on the sunlit edges and at the edge of shadowed craters, featuring lunar crafts, music, and performance art.
# - Subsurface Warrens: A network of protected residential and industrial caverns beneath the surface for radiation shielding, climate control, and specialized manufacturing.
#
# History and Political Outline
# - Founding timeline (fictional):
#   - 2050s–2060s: Early robotic and crewed missions establish a semi-permanent scientific outpost near the south-pole region.
#   - 2080s: First large-scale ISRU facilities prove feasible; a more permanent settlement grows around the rim’s sunlit areas.
#   - 2100s: Luna City is formalized as the capital of a Lunar Union, a cooperative federation of lunar settlements and Earth-based partners.
#   - 2120s–2130s: The Lunar Charter is adopted; Luna City becomes the seat of governance and culture. Tramways, elevators, and a city-wide smart-grid connect districts.
# - Governance: A bicameral-esque structure in practice—an elected City Council representing districts plus a tech-heavy Sovereign Council with scientists, engineers, and resource managers. A City Administrator (similar to a mayor) executes policy and oversees day-to-day operations. International spats with Earth and other spacefaring colonies are handled through the Earth-Lunar Accord and trade councils.
# - Conflicts and tensions (narrative hooks):
#   - Resource disputes over water ice extraction and helium-3 supply chains.
#   - Labor unrest in the Waterworks Quarter as ISRU tech shifts job roles.
#   - Political pressure from Earth-based politics on lunar autonomy and tax regimes.
#   - Environmental ethics debates about mining outside protected areas versus expansion needs.
#
# Economy and Technology
# - Core industries:
#   - ISRU-based production: water, oxygen, fuel, and construction materials manufactured from lunar regolith and ice.
#   - Helium-3 and other scarce isotopes for energy and research.
#   - Solar energy dominance: giant solar farms perched on crater rims feeding the city and export networks.
#   - 3D printing and in-situ construction: regolith-based printers, ceramic and metallic sintering that turn lunar ore into tools, parts, and habitat modules.
#   - Robotics and AI services: maintenance bots, inspection drones, and autonomous cargo loaders.
# - Currency and trade: A dual-credit system with a lunar local currency backed by Earth's financial institutions for Earth-Lunar trade; a separate energy-credit mechanism tied to solar output and ISRU production.
# - Daily life tech: life-support closed loops, urban farming in hydroponics domes, air and water recycling, and compact, shielded habitats designed for 1/6 g.
#
# Culture and Society
# - Identity: A growing “Moonborn” identity that blends Earth cultures with lunar-specific customs. Lunar festivals celebrate the discovery of water ice, long-dawn stories about exploration, and post-scarcity achievements.
# - Language: A lingua franca that blends Earth languages with lunar terms (e.g., “airlock,” “regolith,” “solar ring”). Local dialects emerge in neighborhoods; schools teach STEM, arts, history, and cross-cultural communication.
# - Education and research: Strong emphasis on STEM, space medicine, AI ethics, and planetary geology. Public libraries double as holographic archives and citizen innovation labs.
# - Arts and culture: Lunar music that uses tuning systems adapted to 1/6 g, visual art with reflective glass and regolith pigments, theatre performed in gravity-relieved spaces, and digital-augmented storytelling with immersive projection domes.
#
# Architecture and Infrastructure
# - Design ethos: Fortress-light infrastructure that prioritizes radiation shielding, redundant life support, and modular growth. A mix of underground, shielded, and sunlit architectural zones to balance energy and safety.
# - Materials: Regolith-derived bricks, basalt ceramics, sintered metals, and inflatable modules reinforced by regolith shells.
# - Public spaces: Gravity-friendly plazas, light wells, and “shadow courtyards” to temper solar glare. Transparent domes over major walkways allow for weather-like cycling of heat and climate.
# - Transportation:
#   - Surface maglev and wheel-rail hybrids for short trips within districts.
#   - A lunar elevator network (tethers and mines) connecting surface hubs to higher orbital transfer stations.
#   - Automated cargo drones and robotic taxis for last-mile mobility.
#   - Subterranean transit tunnels link to the Deep Waterworks and Knowledge Quarter.
# - Energy grid: A city-wide solar grid with a few compact nuclear micro-reactors as a backup; advanced energy storage to handle the long lunar day (approx. 14 Earth days of sunlight alternates with 14 days of darkness in some regions, depending on the crater).
#
# Security, Risk, and Health
# - Environmental safeguards: Radiation shielding, air and water purification, and strict pest-free agriculture controls to avoid biosafety risks.
# - Health systems: Lunar medicine focusing on radiation exposure, microgravity effects, and remote health monitoring via telepresence. Hospitals combine robot-assisted surgery, telemedicine, and AI-driven triage.
# - Safety culture: Regular drills for meteor showers, solar storms, and vacuum leaks. Habitats designed with redundant life-support and rapid-seal airlocks.
# - Defense posture: Not a war-focused territory, but a robust, defensive posture against debris, meteor threats, and space weather; diplomacy and alliance-building with Earth and other colonies.
#
# Stories, Scenes, and Plot Hooks
# - A day in Luna City: A journalist or student wakes in a unit with a view over a solar rainbow on the rim, attends a lecture on ISRU, markets in the Night Market Crescent, and ends with a storm warning from the atmospheric dome.
# - Political intrigue: A dispute arises over water rights with a neighboring crater settlement; backroom deals could destabilize the Lunar Union unless transparency is maintained.
# - Scientific mystery: A new underground cavern yields an unusual mineral or energy signature; researchers must decide whether to explore it further, risking contamination or political backlash.
# - Personal stakes: A family balancing work in Waterworks with a child’s schooling in Knowledge Quarter, illustrating the social fabric of a lunar capital.
#
# How to Use Luna City in Your Project
# - If you’re writing fiction, start with a character who moves between districts (administrative, industrial, and cultural centers) to reveal different facets of the city.
# - If you’re designing a game or RPG setting, use the district templates to build missions around resource management, political intrigue, or scientific discovery.
# - If you’re building lore, create a short “lore bible” with map sketches, key NPCs (mayor, chief scientist, port master), and a timeline of major events.
#
# Variants and tweaks you can choose
# - Hard sci-fi version: Emphasize strict ISRU, real-world physics, and plausible energy tech. Fewer magical elements; more procedural storytelling about governance and engineering challenges.
# - Space opera version: More political drama, grand culture clashes, flamboyant architecture, and heroism. Greater emphasis on hero ships, orbital stations, and elite academies.
# - Grimmer cyberpunk variant: Higher tension between corporate interests and citizen life, with surveillance, privatized essential services, and social stratification; more noir mood in daily life.
#
# Would you like me to tailor Luna City to a specific vibe (hard sci-fi, space opera, or dark cyberpunk), or draft a short scene set there? If you have any details you want included (specific tech, district names, or political setup), tell me and I’ll weave them in.

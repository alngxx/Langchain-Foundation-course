# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any      # Import types for more organized code
from tavily import TavilyClient   # Import Tavily search engine helper

tavily_client = TavilyClient()    # Connect to Tavily API

@tool                             # Label this func so LangChain sees it
def web_search(query: str) -> Dict[str, Any]:    # Define function with type hints
    """Search the web for more information"""    # Tell the agent when to use this tool
    return tavily_client.search(query)           # Run the search and return results

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %% [markdown]
# ## Create the Agent

# %%
from langchain.agents import create_agent    # Import agent-building tool
from langgraph.checkpoint.memory import InMemorySaver  # Import "Memory" saver

agent = create_agent(
    model = "gpt-5-nano",                  # 1. Specify the LLM
    tools = [web_search],                  # 2. Specify the tools
    system_prompt = system_prompt,         # 3. Specify the personality
    checkpointer = InMemorySaver()         # 4. Enable memory
)

# %% [markdown]
# ## Running the Chef agent

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages" : [HumanMessage(content = "I have some leftover chicken and rice, what can I cook?")]},
    config
)

print(response["messages"][-1].content)
# Out:
# Nice—leftover chicken and rice are great building blocks. Here are a few simple ideas that work well:
#
# - Chicken fried rice (quick weeknight option)
#   - Why it fits: uses day-old rice, chopped chicken, and a few veggies for a fast pan meal.
#   - Quick outline: sauté onion/garlic, add chicken, stir in rice, push to side, scramble in a couple of eggs, mix in peas or other veg, season with soy sauce.
#   - Time: about 15–20 minutes.
#   - Source inspiration: Easy Peasy Foodie – Leftover Chicken and Egg Fried Rice
#   - Link: https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/
#
# - Creamy chicken and rice casserole
#   - Why it fits: great for using up chicken and rice plus a creamy sauce; makes leftovers easy to reheat.
#   - Quick outline: combine chicken, rice, a creamy sauce (cream of chicken soup or homemade white sauce), cheese, and bake until bubbly.
#   - Time: about 40–60 minutes.
#   - Source inspiration: Crazy for Crust – Easy Chicken and Rice Casserole
#   - Link: https://www.crazyforcrust.com/chicken-and-rice-casserole/
#
# - One-pan garlic herb chicken and rice skillet
#   - Why it fits: simple, one-pot meal with minimal cleanup; you can customize with any veggies you have.
#   - Quick outline: sauté onion, garlic, add chicken pieces to warm, stir in rice and broth, season with herbs, simmer until everything is heated through and the flavors meld.
#   - Time: about 25–35 minutes.
#   - Source idea (one-pan style, commonly shared): inspired by common “leftover chicken and rice skillet” ideas such as a simple pan method from The Recipe Critic’s style posts.
#
# - Leftover chicken and rice “egg fried” rice variation
#   - Why it fits: adds protein and texture with eggs; great if you have peas, carrots, scallions.
#   - Quick outline: similar to fried rice, but you scramble eggs in and toss in leftover rice and chicken with vegetables and soy sauce.
#   - Time: about 15–20 minutes.
#   - Source inspiration: Easy Peasy Foodie (egg fried rice variation)
#
# Would you like me to pull full step-by-step recipes for any of these and tailor them to what you have on hand (specific amounts, any veggies you’ve got, dietary needs, etc.)? If you tell me which option you prefer, I’ll fetch the exact instructions and adapt them to your kitchen.

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice, what can I cook?', additional_kwargs={}, response_metadata={}, id='1b203405-bc22-44c7-8979-6eff9695440d'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 284, 'prompt_tokens': 199, 'total_tokens': 483, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D41Z14UkjT1M6Gj7uGfcaybcogXDo', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c1361-ae2f-7073-a2c0-6a4be4d6d336-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'leftover chicken and rice recipe'}, 'id': 'call_7o7UfBBKCJtJpvCn1uaMB8Il', 'type': 'tool_call'}], usage_metadata={'input_tokens': 199, 'output_tokens': 284, 'total_tokens': 483, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#               ToolMessage(content='{"query": "leftover chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and boom ...", "content": "Recipe Ingredients: 2 cups cooked and chilled rice 1 lb chicken breast, cut into small pieces 2 tablespoons vegetable oil 1 small onion", "score": 0.9055316, "raw_content": null}, {"url": "https://www.facebook.com/groups/2612842568992672/posts/3368384463438475/", "title": "Leftover chicken and rice casserole ideas needed - Facebook", "content": "Dice the leftover chicken while boiling the rice. Put a cup of milk in a saucepan and add a can of cream of chicken soup. As milk/soup mixture", "score": 0.87139857, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie", "content": "Ingredients ; 2 tablespoons olive, rapeseed or coconut oil ; 300-500 g leftover chicken shredded ; 500 g pre-cooked brown rice ; 100 g frozen peas ; 100 g frozen", "score": 0.82492816, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "This Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy", "score": 0.81418616, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! Recipe Video. Prep Time 10 minutes minutes. Cook Time 25", "score": 0.78074646, "raw_content": null}], "response_time": 0.64, "request_id": "0768c30a-7a0b-4f28-9467-f3f625bce18c"}', name='web_search', id='424bea25-5bc3-4578-afb3-111c00f7f0b3', tool_call_id='call_7o7UfBBKCJtJpvCn1uaMB8Il'),
#               AIMessage(content='Nice—leftover chicken and rice are great building blocks. Here are a few simple ideas that work well:\n\n- Chicken fried rice (quick weeknight option)\n  - Why it fits: uses day-old rice, chopped chicken, and a few veggies for a fast pan meal.\n  - Quick outline: sauté onion/garlic, add chicken, stir in rice, push to side, scramble in a couple of eggs, mix in peas or other veg, season with soy sauce.\n  - Time: about 15–20 minutes.\n  - Source inspiration: Easy Peasy Foodie – Leftover Chicken and Egg Fried Rice\n  - Link: https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/\n\n- Creamy chicken and rice casserole\n  - Why it fits: great for using up chicken and rice plus a creamy sauce; makes leftovers easy to reheat.\n  - Quick outline: combine chicken, rice, a creamy sauce (cream of chicken soup or homemade white sauce), cheese, and bake until bubbly.\n  - Time: about 40–60 minutes.\n  - Source inspiration: Crazy for Crust – Easy Chicken and Rice Casserole\n  - Link: https://www.crazyforcrust.com/chicken-and-rice-casserole/\n\n- One-pan garlic herb chicken and rice skillet\n  - Why it fits: simple, one-pot meal with minimal cleanup; you can customize with any veggies you have.\n  - Quick outline: sauté onion, garlic, add chicken pieces to warm, stir in rice and broth, season with herbs, simmer until everything is heated through and the flavors meld.\n  - Time: about 25–35 minutes.\n  - Source idea (one-pan style, commonly shared): inspired by common “leftover chicken and rice skillet” ideas such as a simple pan method from The Recipe Critic’s style posts.\n\n- Leftover chicken and rice “egg fried” rice variation\n  - Why it fits: adds protein and texture with eggs; great if you have peas, carrots, scallions.\n  - Quick outline: similar to fried rice, but you scramble eggs in and toss in leftover rice and chicken with vegetables and soy sauce.\n  - Time: about 15–20 minutes.\n  - Source inspiration: Easy Peasy Foodie (egg fried rice variation)\n\nWould you like me to pull full step-by-step recipes for any of these and tailor them to what you have on hand (specific amounts, any veggies you’ve got, dietary needs, etc.)? If you tell me which option you prefer, I’ll fetch the exact instructions and adapt them to your kitchen.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2152, 'prompt_tokens': 793, 'total_tokens': 2945, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1600, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D41Z6WtNCOmSjJOXgsyVFqXxA30b8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c1361-c2d5-7602-b336-293c5f4e04f0-0', usage_metadata={'input_tokens': 793, 'output_tokens': 2152, 'total_tokens': 2945, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1600}})]}

# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training data goes up to June 2024. I don’t have real-time internet access by default, so I can’t fetch current events or verify changes that happened after that unless a browsing tool is enabled in your environment.
#
# There may be some information from updates after June 2024 if it was included in fine-tuning, but I can’t reliably guarantee accuracy for events or developments after that date.
#
# If you need the latest, I can help you:
# - suggest search terms and reliable sources to check
# - help you evaluate new information you provide
# - summarize timeless concepts or provide general approaches and frameworks
#
# Would you like me to help look up something recent, assuming browsing is available to you?

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.95324475,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.8755427,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.8488849,
#    'raw_content': None},
#   {'url': 'https://en.wikipedia.org/wiki/Daniel_Lurie',
#    'title': 'Daniel Lurie - Wikipedia',
#    'content': 'Daniel Lawrence Lurie (born February 4, 1977) is an American politician and philanthropist who is the 46th and incumbent mayor of San Francisco, serving since',
#    'score': 0.82895297,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/profile--daniel-lurie',
#    'title': 'Daniel Lurie - SF.gov',
#    'content': "Chair, and Mayor of San Francisco. Disaster Council · Office of the Mayor. Mayor Daniel Lurie sworn in as the City's 46th mayor on Jan 8. See recent news. Learn",
#    'score': 0.8194462,
#    'raw_content': None}],
#  'response_time': 0.75,
#  'request_id': 'c2b7a904-79bf-4fe8-9781-37d93e6aff26'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='2a23a5f1-915b-4283-984c-d6e71ea0bf6b'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 416, 'prompt_tokens': 133, 'total_tokens': 549, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D40mUjhlfNYhwDJWINKiSde8aeOjT', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c1333-c5ef-7be3-8f3e-2946d2410b0a-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco 2026 London Breed'}, 'id': 'call_6xKhLRsF6qiBiix6N7dv9Ai6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 133, 'output_tokens': 416, 'total_tokens': 549, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco 2026 London Breed", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.sf.gov/profile--london-breed", "title": "London Breed - SF.gov", "content": "London Nicole Breed was the 45th mayor of the City and County of San Francisco from 2018 until January 2025. Mayor Breed was the first African-American", "score": 0.9995859, "raw_content": null}, {"url": "https://ballotpedia.org/London_Breed", "title": "London Breed - Ballotpedia", "content": "London Breed was the Mayor of San Francisco in California. She assumed office on July 11, 2018. She left office on January 8, 2025.", "score": 0.9994253, "raw_content": null}, {"url": "https://www.nytimes.com/2026/01/16/us/london-breed-san-francisco-mayor-job.html", "title": "What Happened to London Breed, the Former San Francisco Mayor?", "content": "London Breed needs a job, and she wants you to know that. A year ago, she left her post as the 45th mayor of San Francisco — and its", "score": 0.9990746, "raw_content": null}, {"url": "https://www.kqed.org/news/12064904/former-san-francisco-mayor-london-breed-will-not-run-for-congress", "title": "Former San Francisco Mayor London Breed Will Not Run for Congress", "content": "Mayor Daniel Lurie unseated Breed in the November 2024 election. She was the city\'s first Black woman mayor, who served for nearly seven years", "score": 0.9986541, "raw_content": null}, {"url": "https://www.latimes.com/california/story/2024-12-13/san-francisco-mayor-london-breed-says-no-regrets-after-losing-reelection", "title": "After losing reelection, San Francisco mayor says she leaves office ...", "content": "London Breed lost her reelection bid after six years as San Francisco mayor. After tackling a series of crises, including entrenched", "score": 0.99509466, "raw_content": null}], "response_time": 0.67, "request_id": "b7a6d810-8989-48c1-b38f-2f381c2426c2"}', name='web_search', id='278aab75-bc0f-4973-9283-9943ab8276aa', tool_call_id='call_6xKhLRsF6qiBiix6N7dv9Ai6'),
#  AIMessage(content='Daniel Lurie is the current mayor of San Francisco. He took office in January 2025 after defeating London Breed in the November 2024 election. Breed had served as mayor from 2018 until January 2025. If you’d like, I can share official sources or links.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1348, 'prompt_tokens': 724, 'total_tokens': 2072, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1280, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D40mae4adVh0ncX50tltAW94hIuAK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c1333-dd92-73d3-89aa-9810704d3cb9-0', usage_metadata={'input_tokens': 724, 'output_tokens': 1348, 'total_tokens': 2072, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1280}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
